# %%
num = float(input("Enter the number :"))
num = float(input("Enter the Number :"))
# Out:
# Enter the number : 4
# Enter the Number : 5

# %%
add = num+num
sub = num-num
mul = num*num
dev = num/num
sqr = num**num
mod = num%num

# %%
print("add:",add)
print("sub:",sub)
print("mui:",mul)
print("dev:",dev)
print("sqr:",sqr)
print("mod:",mod)
# Out:
# add: 10.0
# sub: 0.0
# mui: 25.0
# dev: 1.0
# sqr: 3125.0
# mod: 0.0
